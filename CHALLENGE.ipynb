# %% [markdown]
# Visual storytelling of one kind or another has been around since caveman were drawing on the walls." Frank Darabont
#
# What good is data without a good plot to tell the story? So, let's take what you've learned about Python Matplotlib and apply it to a real-world situation and dataset
#
# Goodluck from precious - smarthub

# %% [markdown]
# Background
#
# The data is sourced from Pymaceuticals Inc., a burgeoning pharmaceutical company based out of San Diego. Pymaceuticals specializes in anti-cancer pharmaceuticals. In its most recent efforts, it began screening for potential treatments for squamous cell carcinoma (SCC), a commonly occurring form of skin cancer.
#
# These analysis used a complete data from their most recent animal study in two datasets in CSV format. Data set one is Mouse_metadata.csv wich includes 249 mice identified data with SCC tumor growth were treated through a variety of drug regimens, and their Sex, Age_months and Weight (g) identified. The other dataset is Study_results.csv file which includes the results of the study in each columns Mouse I,Timepoint,Tumor Volume (mm3), and Metastatic Sites.
#
# The purpose of this study was to compare the performance of Pymaceuticals' drug of interest, Capomulin, versus the other treatment regimens. You have been tasked by the executive team to generate all of the tables and figures needed for the technical report of the study. The executive team also has asked for a top-level summary of the study results.. For this analysis both datasets imported, merged,cleaned and the aggregate data diplayed in to Python Pandas dataframes, visualized in Matplotlib, and other libraries used in order to make a stastical analysis.

# %% [markdown]
# Instructions Your tasks are to do the following:
#
# 1. Before beginning the analysis, you have two datasets combine them together to create one da2taframe
#
# 2. check the data for any mouse ID with duplicate time points and remove any data associated with that mouse ID.
#
# 3. Use the cleaned data for the remaining steps.
# enerate a summary statistics table consisting of the mean, median, variance, standard deviation, and SEM of the tumor volume for each drug regimen.
#
# 4. Generate a bar plot using both Pandas's DataFrame.plot() and Matplotlib's pyplot that shows the number of total mice for each treatment regimen throughout the course of the study.
#
# 5. Generate a pie plot using both Pandas's DataFrame.plot() and Matplotlib's pyplot that shows the distribution of female or male mice in the study.
#
# 6. Calculate the final tumor volume of each mouse across four of the most promising treatment regimens: Capomulin, Ramicane, Infubinol, and Ceftamin. Calculate the quartiles and IQR and quantitatively determine if there are any potential outliers across all four treatment regimens.
#
# 7. Using Matplotlib, generate a box plot of the final tumor volume for all four treatment regimens and highlight any potential outliers in the plot by changing their color and style.
#
# Hint: All four box plots should be within the same figure.
#
# 8. Select a mouse that was treated with Capomulin and generate a line plot of tumor volume vs. time point for that mouse.
#
# 9. Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin treatment regimen.
#
# 10. Calculate the correlation coefficient and linear regression model between mouse weight and average tumor volume for the Capomulin treatment. Plot the linear regression model on top of the previous scatter plot.
#
# 11. Look across all previously generated figures and tables and write at least three observations or inferences that can be made from the data. Include these observations at the top of notebook.

# %%
import pandas as pd

df = pd.read_csv("python-libraries/Numpy-pandas-matplotlib-course-files/Mouse_metadate.csv")
#print(df)

df2 = pd.read_csv("python-libraries/Numpy-pandas-matplotlib-course-files/Study_results.csv")
#print(df2)
new_df = pd.concat([df, df2], keys =['metadata', 'Study_result'])
new_df
# Out:
# C:\Users\Umah\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                    Age_months Drug Regimen  Metastatic Sites Mouse ID     Sex  \
# metadata     0           21.0     Ramicane               NaN     k403    Male
#              1            3.0    Capomulin               NaN     s185  Female
#              2           16.0    Capomulin               NaN     x401  Female
#              3           22.0    Capomulin               NaN     m601    Male
#              4           11.0     Ramicane               NaN     g791    Male
#              5            1.0     Ramicane               NaN     s508    Male
#              6           16.0    Capomulin               NaN     f966    Male
#              7           18.0     Ramicane               NaN     m546    Male
#              8           11.0     Ramicane               NaN     z578    Male
#              9            4.0     Ramicane               NaN     j913  Female
#              10          18.0    Capomulin               NaN     u364    Male
#              11           4.0     Ramicane               NaN     n364    Male
#              12          17.0    Capomulin               NaN     y793    Male
#              13           8.0    Capomulin               NaN     r554  Female
#              14           3.0    Capomulin               NaN     m957  Female
#              15           9.0     Ramicane               NaN     c758    Male
#              16          20.0    Capomulin               NaN     t565  Female
#              17           7.0     Ramicane               NaN     a644  Female
#              18          10.0     Ramicane               NaN     i177    Male
#              19           8.0     Ramicane               NaN     j989    Male
#              20          23.0    Capomulin               NaN     i738  Female
#              21          13.0     Ramicane               NaN     a520    Male
#              22          24.0    Capomulin               NaN     w914    Male
#              23           9.0     Ramicane               NaN     r811    Male
#              24           3.0    Capomulin               NaN     g288    Male
#              25           8.0     Ramicane               NaN     i334  Female
#              26          18.0     Ramicane               NaN     q610  Female
#              27           8.0     Ramicane               NaN     d251  Female
#              28          17.0    Capomulin               NaN     l897    Male
#              29          23.0     Ramicane               NaN     c458  Female
# ...                       ...          ...               ...      ...     ...
# Study_result 1863         NaN          NaN               1.0     l700     NaN
#              1864         NaN          NaN               1.0     l733     NaN
#              1865         NaN          NaN               4.0     n304     NaN
#              1866         NaN          NaN               4.0     o795     NaN
#              1867         NaN          NaN               3.0     u196     NaN
#              1868         NaN          NaN               3.0     r604     NaN
#              1869         NaN          NaN               4.0     z969     NaN
#              1870         NaN          NaN               1.0     g791     NaN
#              1871         NaN          NaN               3.0     i635     NaN
#              1872         NaN          NaN               4.0     o287     NaN
#              1873         NaN          NaN               1.0     r701     NaN
#              1874         NaN          NaN               1.0     r811     NaN
#              1875         NaN          NaN               2.0     u327     NaN
#              1876         NaN          NaN               2.0     s565     NaN
#              1877         NaN          NaN               2.0     g570     NaN
#              1878         NaN          NaN               1.0     i557     NaN
#              1879         NaN          NaN               1.0     a644     NaN
#              1880         NaN          NaN               1.0     j755     NaN
#              1881         NaN          NaN               4.0     e213     NaN
#              1882         NaN          NaN               4.0     e584     NaN
#              1883         NaN          NaN               4.0     t718     NaN
#              1884         NaN          NaN               2.0     o562     NaN
#              1885         NaN          NaN               3.0     i177     NaN
#              1886         NaN          NaN               4.0     v991     NaN
#              1887         NaN          NaN               3.0     z795     NaN
#              1888         NaN          NaN               2.0     r944     NaN
#              1889         NaN          NaN               3.0     u364     NaN
#              1890         NaN          NaN               1.0     p438     NaN
#              1891         NaN          NaN               4.0     x773     NaN
#              1892         NaN          NaN               2.0     b879     NaN
#
#                    Timepoint  Tumor Volume (mm3)  Weight (g)
# metadata     0           NaN                 NaN        16.0
#              1           NaN                 NaN        17.0
#              2           NaN                 NaN        15.0
#              3           NaN                 NaN        17.0
#              4           NaN                 NaN        16.0
#              5           NaN                 NaN        17.0
#              6           NaN                 NaN        17.0
#              7           NaN                 NaN        16.0
#              8           NaN                 NaN        16.0
#              9           NaN                 NaN        17.0
#              10          NaN                 NaN        17.0
#              11          NaN                 NaN        17.0
#              12          NaN                 NaN        17.0
#              13          NaN                 NaN        17.0
#              14          NaN                 NaN        19.0
#              15          NaN                 NaN        17.0
#              16          NaN                 NaN        17.0
#              17          NaN                 NaN        17.0
#              18          NaN                 NaN        18.0
#              19          NaN                 NaN        19.0
#              20          NaN                 NaN        20.0
#              21          NaN                 NaN        21.0
#              22          NaN                 NaN        21.0
#              23          NaN                 NaN        19.0
#              24          NaN                 NaN        19.0
#              25          NaN                 NaN        20.0
#              26          NaN                 NaN        21.0
#              27          NaN                 NaN        19.0
#              28          NaN                 NaN        19.0
#              29          NaN                 NaN        20.0
# ...                      ...                 ...         ...
# Study_result 1863       45.0           63.946640         NaN
#              1864       45.0           64.299830         NaN
#              1865       45.0           63.586395         NaN
#              1866       45.0           73.059454         NaN
#              1867       45.0           40.667713         NaN
#              1868       45.0           62.670759         NaN
#              1869       45.0           73.867845         NaN
#              1870       45.0           29.128472         NaN
#              1871       45.0           58.633404         NaN
#              1872       45.0           59.741901         NaN
#              1873       45.0           69.778544         NaN
#              1874       45.0           37.225650         NaN
#              1875       45.0           66.268801         NaN
#              1876       45.0           72.588964         NaN
#              1877       45.0           70.492788         NaN
#              1878       45.0           47.685963         NaN
#              1879       45.0           32.978522         NaN
#              1880       45.0           69.563621         NaN
#              1881       45.0           63.105696         NaN
#              1882       45.0           68.359777         NaN
#              1883       45.0           63.423695         NaN
#              1884       45.0           72.455421         NaN
#              1885       45.0           33.562402         NaN
#              1886       45.0           70.167749         NaN
#              1887       45.0           65.741070         NaN
#              1888       45.0           41.581521         NaN
#              1889       45.0           31.023923         NaN
#              1890       45.0           61.433892         NaN
#              1891       45.0           58.634971         NaN
#              1892       45.0           72.555239         NaN
#
# [2142 rows x 8 columns]

# %%
new_df.drop_duplicates('Timepoint')
# Out:
#                    Age_months Drug Regimen  Metastatic Sites Mouse ID   Sex  \
# metadata     0           21.0     Ramicane               NaN     k403  Male
# Study_result 0            NaN          NaN               0.0     b128   NaN
#              250          NaN          NaN               0.0     a275   NaN
#              488          NaN          NaN               1.0     e291   NaN
#              711          NaN          NaN               0.0     q597   NaN
#              918          NaN          NaN               2.0     u364   NaN
#              1113         NaN          NaN               0.0     u149   NaN
#              1296         NaN          NaN               3.0     m650   NaN
#              1467         NaN          NaN               2.0     i334   NaN
#              1621         NaN          NaN               4.0     a262   NaN
#              1763         NaN          NaN               1.0     n364   NaN
#
#                    Timepoint  Tumor Volume (mm3)  Weight (g)
# metadata     0           NaN                 NaN        16.0
# Study_result 0           0.0           45.000000         NaN
#              250         5.0           46.795257         NaN
#              488        10.0           48.529741         NaN
#              711        15.0           41.395660         NaN
#              918        20.0           40.343948         NaN
#              1113       25.0           52.925348         NaN
#              1296       30.0           64.901888         NaN
#              1467       35.0           39.769552         NaN
#              1621       40.0           69.592732         NaN
#              1763       45.0           31.095335         NaN

# %%
new_df.describe()
# Out:
#        Age_months  Metastatic Sites    Timepoint  Tumor Volume (mm3)  \
# count  249.000000       1893.000000  1893.000000         1893.000000
# mean    12.730924          1.021659    19.572108           50.448381
# std      7.228687          1.137974    14.079460            8.894722
# min      1.000000          0.000000     0.000000           22.050126
# 25%      6.000000          0.000000     5.000000           45.000000
# 50%     13.000000          1.000000    20.000000           48.951474
# 75%     19.000000          2.000000    30.000000           56.292200
# max     24.000000          4.000000    45.000000           78.567014
#
#        Weight (g)
# count  249.000000
# mean    26.116466
# std      3.697003
# min     15.000000
# 25%     25.000000
# 50%     27.000000
# 75%     29.000000
# max     30.000000

# %%
import matplotlib.pyplot as plt
import pandas as pd

new_df.plot.bar(color = 'b')
plt.xlabel('Mouse ID')
plt.ylabel('Drug Regimen')
plt.title('Count of Mouse')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


df = pd.read_csv("python-libraries/Numpy-pandas-matplotlib-course-files/Mouse_metadate.csv")
#print(df)
group_sex= df.groupby('Sex')

plt.pie('')
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-34cbc0e29f1f> in <module>
#       8 group_sex= df.groupby('Sex')
#       9
# ---> 10 plt.pie('group_sex')
#      11 plt.show
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2779         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2780         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2781         data is not None else {}))
#    2782
#    2783
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels)
#    2964         # The use of float32 is "historical", but can't be changed without
#    2965         # regenerating the test baselines.
# -> 2966         x = np.asarray(x, np.float32)
#    2967         if x.ndim != 1 and x.squeeze().ndim <= 1:
#    2968             cbook.warn_deprecated(
#
# ~\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: 'group_sex'

# %%
import matplotlib.pyplot as plt
import pandas as pd

df2 = pd.read_csv("python-libraries/Numpy-pandas-matplotlib-course-files/Study_results.csv")
print(df2)
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# 5        h246          0           45.000000                 0
# 6        p189          0           45.000000                 0
# 7        n923          0           45.000000                 0
# 8        q119          0           45.000000                 0
# 9        f993          0           45.000000                 0
# 10       z234          0           45.000000                 0
# 11       b559          0           45.000000                 0
# 12       y260          0           45.000000                 0
# 13       x930          0           45.000000                 0
# 14       o725          0           45.000000                 0
# 15       z969          0           45.000000                 0
# 16       v835          0           45.000000                 0
# 17       r604          0           45.000000                 0
# 18       n304          0           45.000000                 0
# 19       l700          0           45.000000                 0
# 20       x336          0           45.000000                 0
# 21       l725          0           45.000000                 0
# 22       m133          0           45.000000                 0
# 23       v295          0           45.000000                 0
# 24       a818          0           45.000000                 0
# 25       y601          0           45.000000                 0
# 26       t724          0           45.000000                 0
# 27       k382          0           45.000000                 0
# 28       w422          0           45.000000                 0
# 29       c326          0           45.000000                 0
# ...       ...        ...                 ...               ...
# 1863     l700         45           63.946640                 1
# 1864     l733         45           64.299830                 1
# 1865     n304         45           63.586395                 4
# 1866     o795         45           73.059454                 4
# 1867     u196         45           40.667713                 3
# 1868     r604         45           62.670759                 3
# 1869     z969         45           73.867845                 4
# 1870     g791         45           29.128472                 1
# 1871     i635         45           58.633404                 3
# 1872     o287         45           59.741901                 4
# 1873     r701         45           69.778544                 1
# 1874     r811         45           37.225650                 1
# 1875     u327         45           66.268801                 2
# 1876     s565         45           72.588964                 2
# 1877     g570         45           70.492788                 2
# 1878     i557         45           47.685963                 1
# 1879     a644         45           32.978522                 1
# 1880     j755         45           69.563621                 1
# 1881     e213         45           63.105696                 4
# 1882     e584         45           68.359777                 4
# 1883     t718         45           63.423695                 4
# 1884     o562         45           72.455421                 2
# 1885     i177         45           33.562402                 3
# 1886     v991         45           70.167749                 4
# 1887     z795         45           65.741070                 3
# 1888     r944         45           41.581521                 2
# 1889     u364         45           31.023923                 3
# 1890     p438         45           61.433892                 1
# 1891     x773         45           58.634971                 4
# 1892     b879         45           72.555239                 2
#
# [1893 rows x 4 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1893 entries, 0 to 1892
# Data columns (total 4 columns):
# Mouse ID              1893 non-null object
# Timepoint             1893 non-null int64
# Tumor Volume (mm3)    1893 non-null float64
# Metastatic Sites      1893 non-null int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 59.2+ KB

# %%
df2.describe()
# Out:
#          Timepoint  Tumor Volume (mm3)  Metastatic Sites
# count  1893.000000         1893.000000       1893.000000
# mean     19.572108           50.448381          1.021659
# std      14.079460            8.894722          1.137974
# min       0.000000           22.050126          0.000000
# 25%       5.000000           45.000000          0.000000
# 50%      20.000000           48.951474          1.000000
# 75%      30.000000           56.292200          2.000000
# max      45.000000           78.567014          4.000000

# %%
plt.title('Sports Watch Data')
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume')

plt.plot(x, y)
# plt.grid()

# specify the axis you wan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-fa38bf33be47> in <module>
#       3 plt.ylabel('Tumor Volume')
#       4
# ----> 5 plt.plot(x, y)
#       6 # plt.grid()
#       7
#
# NameError: name 'x' is not defined

# %%
plt.title('anything')
plt.xlabel('Tumor Volume')
plt.ylabel('Timepoint')

plt.plot(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c5527a69efcb> in <module>
#       3 plt.ylabel('Timepoint')
#       4
# ----> 5 plt.plot(x, y)
#
# NameError: name 'x' is not defined
